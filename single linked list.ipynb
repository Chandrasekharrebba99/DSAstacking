# %% [markdown]
# # linked list implementation

# %% [markdown]
# ## created a first Node

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
        
class linkedlist:
    def __init__(self):
        self.head = None
    def insertdata(self,newNode):
        if(self.head is None):
            self.head = newNode
    


#node = [data|next]
#first Node = [john|None]

firstnode = Node("john")

Linkedlist = linkedlist()
Linkedlist.insertdata(firstnode)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
        
class linkedlist:
    def __init__(self):
        self.head = None
    def insertdata(self,newNode):
        if(self.head is None):
            self.head = newNode


#node = [data|next]
#first Node = [john|None]

firstnode = Node("john")

Linkedlist = linkedlist()
d =Linkedlist.insertdata(firstnode)

# %% [markdown]
# # single linked list insertion at the end

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("ITs Empty")
        currentNode = self.head
        while True:
            if(currentNode is None):
                break
            print(currentNode.data)
            currentNode = currentNode.next
f1 = Node("JOe")
linkedlist = Linkedlist()
linkedlist.insert(f1)

f2 = Node("SRu")
linkedlist.insert(f2)

f3 = Node("Chi")
linkedlist.insert(f3)

f4 = Node("bro")
linkedlist.insert(f4)

linkedlist.printL()
# Out:
# JOe
# SRu
# Chi
# bro

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("ITs Empty")
        currentNode = self.head
        while True:
            if(currentNode is None):
                break
            print(currentNode.data)
            currentNode = currentNode.next
f1 = Node("JOe")
linkedlist = Linkedlist()
#linkedlist.insert(f1)



linkedlist.printL()
# Out:
# ITs Empty

# %% [markdown]
# # Practice

# %%
print("HEllo world")
# Out:
# HEllo world

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("ITs Empty")
        currentNode = self.head
        while(True):
            if(currentNode is None):
                break
            print(currentNode.data)
            currentNode = currentNode.next
            
s0  = Node("node1")
linkedlist = Linkedlist()
linkedlist.insert(s0)


s1 = Node("node2")
linkedlist.insert(s1)

s2 = Node("node3")
linkedlist.insert(s2)

linkedlist.printL()
# Out:
# node1
# node2
# node3

# %%
 def printL(self):
        if(self.head is None):
            print("ITs Empty")
        currentNode = self.head
        while True:
            if(currentNode is None):
                break
            print(currentNode.data)
            currentNode = currentNode.next

# %% [markdown]
# # insert a Node at the Head

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def inserthead(self,newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode
    def insertend(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("ITs Empty")
        currentNode = self.head
        while True:
            if(currentNode is None):
                break
            print(currentNode.data)
            currentNode = currentNode.next
f1 = Node("JOe")
linkedlist = Linkedlist()
linkedlist.insertend(f1)

f2 = Node("SRu")
linkedlist.insertend(f2)

f3 = Node("Chi")
linkedlist.insertend(f3)

f4 = Node("bro")
linkedlist.inserthead(f4)

linkedlist.printL()
# Out:
# bro
# JOe
# SRu
# Chi

# %%
Arr = [12312,123,1,23,12,312,3,12]

for i in range(len(Arr)):
    minidx = i
    for j in range(i+1,len(Arr)):
        if(Arr[minidx] > Arr[j]):
            minidx = j
    Arr[i],Arr[minidx] = Arr[minidx],Arr[i]

print(Arr)
# Out:
# [1, 3, 12, 12, 23, 123, 312, 12312]

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # linked list reverse

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
        
    def inserthead(self,newNode):
        temp = self.head
        self.head = newNode
        self.head.next = temp
        del temp
        
    def reverse(self):
        prev = None
        current = self.head
        while(current is not None):
            next = current.next
            current.next = prev
            prev = current
            current = next
        self.head = prev
        
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def PrintLL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(currentNode.data)
                currentNode = currentNode.next

s0 = Node("Chintu")
linkedlist = Linkedlist()
linkedlist.insert(s0)

s1 = Node("sru")
linkedlist.insert(s1)


s2 = Node("bob")
linkedlist.inserthead(s2)
#linkedlist.reverse()

linkedlist.PrintLL()
# Out:
# bob
# Chintu
# sru

# %% [markdown]
# #  insert a node in between or after

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def  __init__(self):
        self.head = None
    def lllength(self):
        length = 0
        cNode = self.head
        while cNode is not None:
            length +=1
            cNode = cNode.next
    def midNode(self):
        mid = 2
        tempNode = self.head
        tempPosition = 0
        while True:
            if(mid == tempPosition):
                return tempNode.data
                break
            tempNode = tempNode.next
            tempPosition+=1   
    def insertat(self,newNode,position):
        #head=>09=>19=>32=>34=>null
        currentNode = self.head
        currentPosition = 0
        while True:
            if(currentPosition == position):
                previousNode.next = newNode
                newNode.next = currentNode
                break
            previousNode = currentNode
            currentNode = currentNode.next
            currentPosition +=1
        
        
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    
    def firstNode(self):
            print(self.head.data)
    
    #print the last Node agiain
    
    def printlast(self):
        temp = self.head
        while True:
            if(temp.next is None):
                print("My last Node is",temp.data)
                break
            temp = temp.next
    
    def printl(self):
        if(self.head is None):
            print("Its Empty")
        
        else:
            currentNode = self.head
            count =0
            while True:
                if(currentNode is None):
                    break
                print(count,currentNode.data)
                currentNode = currentNode.next
                count+=1

s0 = Node("node1")
ll = linkedlist()
ll.insert(s0)

s1 = Node("dac")
ll.insert(s1)

s2 = Node("chintu")
ll.insert(s2)

s3 = Node("dsv")
ll.insertat(s3,1)

ll.printlast()

ll.lllength()
ll.printl()
ll.firstNode()
print("MId element")
ll.midNode()
# Out:
# My last Node is chintu
# 0 qd
# 1 dsv
# 2 dac
# 3 chintu
# qd
# MId element
# 'dac'

# %%
#print the first Node

def firstNode(self):
        print(self.head)
ll.firstNode()
# Out:
# qd

# %% [markdown]
# # printing the lastNode

# %%
def printlastNode(self):
    temp = self.head
    while True:
        if(temp.next is None):
            print("My last Node is",temp.data)
            break
        temp = temp.next

ll.printlast()
# Out:
# My last Node is chintu

# %% [markdown]
# # print the length of the linked list

# %%
def lllength(self):
        length = 0
        cNode = self.head
        while cNode is not None:
            length +=1
            cNode = cNode.next
        
        return length

ll.lllength()
# Out:
# 4

# %% [markdown]
# # print the middle Node

# %%
def midNode(self):
        mid = 2
        tempNode = self.head
        tempPosition = 0
        while True:
            if(mid == tempPosition):
                return tempNode.data
                break
            tempNode = tempNode.next
            tempPosition+=1
ll.midNode()
# Out:
# 'dac'

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def Insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode=self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(currentNode.data)
                currentNode = currentNode.next
    def lastNodeP(self):
        if(self.head.next is None):
            return self.head
        else: 
            lastNode=self.head
            while True:
                if lastNode.next is None:
                    print(lastNode)
                lastNode = lastNode.next
                
                
                
            

            
            
            
s0 = Node("CH")            
ll = Linkedlist()
ll.Insert(s0)

s1 = Node("in")
ll.Insert(s1)

s2 = Node("tu")
ll.Insert(s2)



ll.lastNodeP()
ll.printL()
ll.lastNodeP()
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9f90121a1222> in <module>
#      55
#      56
# ---> 57 ll.lastNodeP()
#      58 ll.printL()
#      59 ll.lastNodeP()
#
# <ipython-input-4-9f90121a1222> in lastNodeP(self)
#      32             lastNode=self.head
#      33             while True:
# ---> 34                 if lastNode.next is None:
#      35                     print(lastNode)
#      36                 lastNode = lastNode.next
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
class Node:
    def __init__(self,data):
        self.data = data 
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None 
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def inserthead(self,newNode):
        tempNode = self.head
        self.head = newNode
        newNode.next = tempNode
        del tempNode
        
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            count =0 
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(count,currentNode.data)
                count = count+1
                currentNode = currentNode.next
    def find(self):
        temp = self.head
        print(temp.data)
    def length(self):
        if(self.head is None):
            print(0)
        count = 0
        while self.head is not None:
                count +=1
                self.head = self.head.next
        print(count)
            
        

s0 = Node("Chintu")
ll = Linkedlist()
ll.insert(s0)


s1 = Node("chandu")
ll.insert(s1)

s2 = Node("Rebba")
ll.insert(s2)

s3 = Node("sekhar")
ll.inserthead(s3)

s4 = Node("What")
ll.insert(s4)

ll.printL()
print("Length of the Linkedlist")
ll.length()

print("Find element at Position:n is")
#ll.midNode()
# Out:
# 0 sekhar
# 1 Chintu
# 2 chandu
# 3 Rebba
# 4 What
# Length of the Linkedlist
# 5
# Find element at Position:n is

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insertHead(self,newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode
    def printposition(self):
        
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode =lastNode.next
            lastNode.next = newNode
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(currentNode.data)
                currentNode = currentNode.next

s0 = Node("Chinr")
ll = Linkedlist()
ll.insert(s0)


s1 = Node("FirstNode")
ll.insert(s1)

s2 = Node("Secondnode ")
ll.insert(s2)

s3 = Node("thirdNode")
ll.insertHead(s3)
ll.printL()
# Out:
# thirdNode
# Chinr
# FirstNode
# Secondnode

# %%
arr = [12,4,312,3,21,423]
for i in range(len(arr)):
    for j in range(i,len(arr)):
        for k in range(i,j+1):
            print(arr[k])
        print("\n")
# Out:
# 12
#
#
# 12
# 4
#
#
# 12
# 4
# 312
#
#
# 12
# 4
# 312
# 3
#
#
# 12
# 4
# 312
# 3
# 21
#
#
# 12
# 4
# 312
# 3
# 21
# 423
#
#
# 4
#
#
# 4
# 312
#
#
# 4
# 312
# 3
#
#
# 4
# 312
# 3
# 21
#
#
# 4
# 312
# 3
# 21
# 423
#
#
# 312
#
#
# 312
# 3
#
#
# 312
# 3
# 21
#
#
# 312
# 3
# 21
# 423
#
#
# 3
#
#
# 3
# 21
#
#
# 3
# 21
# 423
#
#
# 21
#
#
# 21
# 423
#
#
# 423

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insertLast(self,newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode
    def insertat(self,newNode,position):
        #head=>chintu=>rebba=>cutie=>wwe=>None
        currentposition = 0
        currentNode = self.head
        while True:
            if(currentposition == position):
                prevNode.next = newNode
                newNode.next = currentNode
                break
            prevNode = currentNode
            currentNode = currentNode.next
            currentposition +=1
        
    def LengthLL(self):
        if(self.head is None):
            print(0)
        count = 1
        newNode = self.head
        while True:
            if(newNode.next is None):
                break
            newNode = newNode.next
            count+=1
        return count
    
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
            
    def delEnd(self):
            lastNode = self.head
            while lastNode.next is not None:
                    previousNode = lastNode
                    lastNode = lastNode.next
            previousNode.next = None
            
    def delat(self,position):
        if(position<0 and position>ll.LengthLL()):
            print("Invalid position")
        else:
            currentNode = self.head
            currentposition=0
            while True:
                if(currentposition == position):
                    prevNode.next =currentNode.next
                    currentNode.next=None
                    break
                prevNode = currentNode
                currentNode = currentNode.next
                currentposition +=1
        
        
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            count =0
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(count,currentNode.data)
                count+=1
                currentNode = currentNode.next

                
s0 = Node("Hello")
ll = Linkedlist()
ll.insert(s0)


s1 = Node("Chint")
ll.insert(s1)

s2 = Node("Rebba")
ll.insert(s2)

s3 = Node("Sru")
ll.insert(s3)

s4 = Node("LastNode")
ll.insertLast(s4)

s5 = Node("MiddleNode")
ll.insertat(s5,2)


ll.printL()

#ll.delEnd()
ll.delat(2)
ll.LengthLL()


print("\nnewlist delete a node at postion 2 \n")
ll.printL()

print("\n delete the last Node\n")
ll.delEnd()
ll.printL()

ll.LengthLL()
#ll.check()
# Out:
# 0 LastNode
# 1 Hello
# 2 MiddleNode
# 3 Chint
# 4 Rebba
# 5 Sru
#
# newlist delete a node at postion 2
#
# 0 LastNode
# 1 Hello
# 2 Chint
# 3 Rebba
# 4 Sru
#
#  delete the last Node
#
# 0 LastNode
# 1 Hello
# 2 Chint
# 3 Rebba
# 4

# %%
0 LastNode
1 Hello
2 MiddleNode
3 Chint
4 Rebba
5 Sru
('Length of LL', 5)

# %% [markdown]
# # delete node at position

# %%
def delat(self,position):
        if(position<0 or position>ll.LengthLL()):
            print("Invalid position")
        if(self.isListEmpty() is False):
            if position is 0:
                self.deleteHead()
                return
            currentNode = self.head
            currentposition=0
            while True:
                if(currentposition == position):
                    prevNode.next =currentNode.next
                    currentNode.next=None
                    break
                prevNode = currentNode
                currentNode = currentNode.next
                currentposition +=1
ll.delat(2)
# Out:
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\chandu\AppData\Local\Temp/ipykernel_2700/3773601384.py:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if position is 0:

# %% [markdown]
# # merge two sorted Linked List

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def mergeList1(self,firstList,mergedList,secondList):
        currentfirst = firstList.head
        currentsecound = secondList.head
        while True:
            if currentfirst is None:
                mergedList.insert(currentfirst)
                break
            if currentsecound is None:
                mergedList.insert(secondList)
                break
            if(currentfirst.data < currentsecound.data):
                currentfirstnext = currentfirst.next
                currentfirst.next = None
                mergedList.insert(currentfirst)
                currentfirst = currentfirstnext
            else:
                currentsecoundnext =currentsecound.next
                currentsecound.next = None
                mergedList.insert(currentsecound)
                currentsecound = currentsecoundnext
        
        
        
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(currentNode.data)
                currentNode = currentNode.next
    
s0 = Node(1)
LL1 = Linkedlist()
LL1.insert(s0)

s1 = Node(3)
LL1.insert(s1)

s2= Node(5)
LL1.insert(s2)

LL1.printL()
# Out:
# 1
# 3
# 5

# %%
f0 =Node(1)
f1 = Node(3)
f2 = Node(4)

firstList =Linkedlist()
firstList.insert(f0)
firstList.insert(f1)
firstList.insert(f2)

firstList.printL()
# Out:
# 1
# 3
# 4

# %%
s0 = Node(2)
s1 = Node(7)
s2 = Node(9)

secondList = Linkedlist()
secondList.insert(s0)
secondList.insert(s1)
secondList.insert(s2)
secondList.printL()
# Out:
# 2
# 7
# 9

# %%
#def mergeList(self):

print("FirstList is ")
firstList.printL()
print("SecondList is ")
secondList.printL()

mergeList = Linkedlist()
#mergeLists(firstList,secondList,mergeList)

ll = Linkedlist()
mergeList.mergeList1(firstList,mergeList,secondList)
print("Merged List is")
mergeList.printL()
# Out:
# FirstList is
# 1
# 3
# 4
# SecondList is
# 2
# 7
# 9
# Merged List is
# 1
# 2
# 3
# 4

# %% [markdown]
# # Entering Nodes in a simulation

# %%
print("Enter The Number of Nodes:")
num = int(input())
LL3 = Linkedlist()
for i in range(num):
    print("Enter Node")
    nums = input()
    s0 = Node(nums)
    LL3.insert(s0)
    
print("\n\nYour LinkedList is")
l1 = LL3.printL()
l1
# Out:
# Enter The Number of Nodes:
# 5
# Enter Node
# 32
# Enter Node
# 23
# Enter Node
# jhb
# Enter Node
# jhv
# Enter Node
# 5
#
#
# Your LinkedList is
# 32
# 23
# jhb
# jhv
# 5

# %%
#practise
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,newNode):
        if(self.head is None):
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if(lastNode.next is None):
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    def insertat(self,newNode,position):
        currentpostion = 0
        currentNode = self.head
        while True:
            if(currentpostion ==position):
                prevNode.next = newNode
                newNode.next = currentNode
                break
            prevNode = currentNode
            currentNode = currentNode.next
            currentpostion +=1
    def findpos(self,findNode):
        #print(self.head.data)
        if(self.head == findNode):
            print("0")
        else:
            tempNode = self.head
            position = 1
            try:
                while True:
                    if(tempNode.data == findNode.data):
                        print(position)
                    tempNode = tempNode.next
                    position +=1
            except AttributeError:
                pass
    def inserthead(self,newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode
    def printL(self):
        if(self.head is None):
            print("Its Empty")
        else:
            currentNode = self.head
            while True:
                if(currentNode is None):
                    break
                print(currentNode.data)
                currentNode = currentNode.next

            
            
s0 = Node("Hello")
ll = Linkedlist()
ll.insert(s0)

s1 = Node("Chintu")
ll.insert(s1)

s2 = Node("rvev")
ll.insert(s2)

s3 = Node("rebba")
ll.insertat(s3,1)

s4=Node("First")
ll.inserthead(s4)




ll.printL()
ll.findpos(s1)
# Out:
# First
# Hello
# rebba
# Chintu
# rvev
# 4

# %%
class Schooldata:
    def __init__(self,name,age,gender,SSC):
        self.name = name 
        self.age = age
        self.gender = gender
        self.ssc = SSC
class college:
    def __init__(self):

# %%
import numpy as np
A = []
n =int(input())

for i in range(n):
    A.append([])
for i in range(n):
    for j in range(n):
        num = int(input())
        A[i].append(num)
s = int(input())

newarr=[]
for i in range(n):
    newarr.append([])
    for j in range(n):
        if(i == j):
            newarr[i].append(s)
        else:
            newarr[i].append(0)

A1 = np.mat(A)
A2 = np.mat(newarr)

c = A1*A2
print(c)

# %%
4+4+8+9+7+7+7+7
# Out:
# 53

# %%
53/8
# Out:
# 6.625

# %%
4+4+10+9+7+7+7+7
# Out:
# 55

# %%
55/8
# Out:
# 6.875

# %%
4+7+10+9+7+7+7+7
# Out:
# 58

# %%
58/8
# Out:
# 7.25

# %%
7+4+7+10+7+7+7+7
# Out:
# 56

# %%
56/8
# Out:
# 7.0

# %%
4+4+10+10+7+7+7+7
# Out:
# 56

# %%
40+40
# Out:
# 80

# %%
80/2
# Out:
# 40.0

# %%
# Out:
# 70

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
    
class Linkedlist:
    def __init__(self,newNode):
        self.head = None
    def insert(self):

# %%
#paindrome
num = int(input("Enter a number"))

sumi = 0
while num>0:
    r = num%10
    sumi = (sumi*10)+r
    num = num//10
print(sumi)
# Out:
# Enter a number7257356
# 6537527

# %%
#fibu
n0 = 0
n1 = 1
